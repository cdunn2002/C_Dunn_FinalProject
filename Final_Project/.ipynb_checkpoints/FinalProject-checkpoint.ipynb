# %%
import pandas as pd
import numpy as np
import netCDF4 as nc
import xarray as xr 
import matplotlib.pyplot as plt
import datetime as dt

# %%
filepath = 'Final.Project/deployment0001_CE01ISSP-SP001-06-NUTNRJ000-recovered_cspp-nutnr_j_cspp_instrument_recovered_20140417T222823.449000-20140514T070004.817000.nc'
data_nitrate = xr.open_dataset(filepath)
# Out:
# /opt/conda/lib/python3.10/site-packages/xarray/coding/times.py:254: RuntimeWarning: invalid value encountered in cast
#   flat_num_dates_ns_int = (flat_num_dates * _NS_PER_TIME_DELTA[delta]).astype(

# %%
data = data_nitrate.where(data_nitrate.time.dt.month == 4, drop=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/xarray/coding/times.py:254: RuntimeWarning: invalid value encountered in cast
#   flat_num_dates_ns_int = (flat_num_dates * _NS_PER_TIME_DELTA[delta]).astype(

# %%
# Getting values for depth and nitrate
nitrate = data.nitrate_concentration.values
depth = data.depth.values

# %%
# Find average nitrate per depth
rounded_depth = np.round(depth)
var = pd.DataFrame(data = {'Depth': rounded_depth, 'Nitrate': nitrate}, columns = ['Depth','Nitrate'])
var = var.groupby(['Depth']).mean()
display(var)
# Out:
#          Nitrate
# Depth
# 0.0     0.607000
# 1.0     0.275833
# 2.0    -0.547238
# 3.0     0.712682
# 4.0     0.258727
# 5.0     0.958000
# 6.0     0.064462
# 7.0     0.832696
# 8.0     0.999227
# 9.0     0.463905
# 10.0    3.219812
# 11.0    1.419769
# 12.0    1.676091
# 13.0    1.469100
# 14.0    4.222550
# 15.0    6.785500
# 16.0    3.604450
# 17.0    3.956524
# 18.0    4.695542
# 19.0    7.481880
# 20.0    9.579429
# 21.0    6.687294
# 22.0    5.101800
# 23.0   11.350546
# 24.0   11.255000

# %%
# Plot nitrate and oxygen 
# Make figure
fig,axs = plt.subplots(figsize=(8,8))
 

# Plot temperature and pressure
x = var.Nitrate
y = var.index
axs.scatter(x, y, color='k', lw=2, marker='o')


# Format figure
axs.invert_yaxis()
axs.grid()
# make a title and set axes labels, maybe increase font size
axs.set_title('Nitrate vs. Depth profile')
axs.set_xlabel('Nitrate (uMol L-1)', fontsize=16)
axs.set_ylabel('Depth (m)', fontsize=16)
axs.plot()
plt.savefig('figure1ocean215.png')

# %%
# Phytoplankton Growth
filepath = '2010sConditionsNopHResponse.nc'
data_phyto = xr.open_dataset(filepath)
display(data_phyto)
# Out:
# <xarray.Dataset>
# Dimensions:                          (t: 101, b: 89, z: 7)
# Coordinates:
#   * t                                (t) datetime64[ns] 2012-12-31T14:00:00 ....
# Dimensions without coordinates: b, z
# Data variables: (12/1611)
#     volume                           (t, b, z) float64 ...
#     hdsource                         (t, b, z) float64 ...
#     hdsink                           (t, b, z) float64 ...
#     eflux                            (t, b, z) float64 ...
#     vflux                            (t, b, z) float64 ...
#     porosity                         (t, b, z) float64 ...
#     ...                               ...
#     Filter_Shallow_Cover             (t, b) float64 ...
#     Filter_Deep_Cover                (t, b) float64 ...
#     Filter_Other_Cover               (t, b) float64 ...
#     Black_Coral_Cover                (t, b) float64 ...
#     Stony_Coral_Cover                (t, b) float64 ...
#     Soft_Coral_Cover                 (t, b) float64 ...
# Attributes:
#     title:       California
#     geometry:    CalCurrentV3_utm.bgm
#     parameters:  atlantismain -i DIVCalCurrentV3_Biol.nc 0 -o outputCCV3.nc -...
#     wcnz:        6
#     sednz:       1

# %%
# Variable I want 'PicoPhytopl_N'
picophytopl_data = data_phyto['PicoPhytopl_N'].values

oxygen_data = data_phyto['Oxygen'].values

# %%
# Getting dimensions of the data set
print("Dimensions of picophytopl_data:", np.ndim(picophytopl_data))

flatphyto_data = picophytopl_data.flatten()
# Out:
# Dimensions of picophytopl_data: 3

# %%
# Rounding our values for a more easily digestable graph
rounded_oxygen = np.round(oxygen_data, 1)
rounded_picophytopl_data = np.round(picophytopl_data, 1)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# 3D graph for Phytoplankton (3 dimensional data)
picophytopl_data = data_phyto['PicoPhytopl_N'].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d') 

# Plotting the phytoplankton data
ax.scatter(picophytopl_data[0], picophytopl_data[1], picophytopl_data[2])
ax.set_title('Phytoplankton Data')
x_max = 2.5
x_min = 0.0
ax.set_xlim([x_min, x_max])
ax.set_xlabel('Biomass (mg N m^-3)')
ax.set_ylabel('Length (m)')
z_max = 20
z_min = 0
ax.set_zlim([z_max, z_min])
ax.set_zlabel('Depth (m)')

# Show the plot
plt.show()
plt.savefig('figure2ocean215.png')

# %%
# Create filepath
filepath = 'UW_O2_V1_1.09254.WMO5904395.AA4330.nc'
data_oxygen = xr.open_dataset(filepath)
display(data_oxygen)
# Out:
# <xarray.Dataset>
# Dimensions:                    (WMO_id3: 1, WMO_id2: 7, float_id3: 1,
#                                 float_id2: 4, nprofiles3: 1, nprofiles2: 1,
#                                 nprofiles1: 1, n_corr_O2_profiles3: 1,
#                                 n_corr_O2_profiles2: 1, n_corr_O2_profiles1: 1,
#                                 profile3: 1, profile2: 1, profile1: 85,
#                                 lat3: 1, lat2: 1, lat1: 85, lon3: 1, lon2: 1,
#                                 ...
#                                 pct_error_O2cal_deep3: 1,
#                                 pct_error_O2cal_deep2: 1,
#                                 pct_error_O2cal_deep1: 1,
#                                 pct_error_O2cal_surf3: 1,
#                                 pct_error_O2cal_surf2: 1,
#                                 pct_error_O2cal_surf1: 1, NOTES3: 1, NOTES2: 1)
# Dimensions without coordinates: WMO_id3, WMO_id2, float_id3, float_id2,
#                                 nprofiles3, nprofiles2, nprofiles1,
#                                 n_corr_O2_profiles3, n_corr_O2_profiles2,
#                                 n_corr_O2_profiles1, profile3, profile2,
#                                 profile1, lat3, lat2, lat1, lon3, lon2, lon1,
#                                 basin3, basin2, DATESTR3, DATESTR2, TIMESTR3,
#                                 ...
#                                 est_error_O2cal_surf1, pct_error_O2cal3,
#                                 pct_error_O2cal2, pct_error_O2cal1,
#                                 pct_error_O2cal_deep3, pct_error_O2cal_deep2,
#                                 pct_error_O2cal_deep1, pct_error_O2cal_surf3,
#                                 pct_error_O2cal_surf2, pct_error_O2cal_surf1,
#                                 NOTES3, NOTES2
# Data variables: (12/47)
#     WMO_FLOAT_ID               (WMO_id3, WMO_id2) |S1 ...
#     UW_FLOAT_ID                (float_id3, float_id2) |S1 ...
#     NPROFILES                  (nprofiles3, nprofiles2, nprofiles1) float64 ...
#     N_CORR_O2_PROFILES         (n_corr_O2_profiles3, n_corr_O2_profiles2, n_corr_O2_profiles1) float64 ...
#     PROFILE                    (profile3, profile2, profile1) float64 ...
#     LATITUDE                   (lat3, lat2, lat1) float64 ...
#     ...                         ...
#     EST_ERROR_O2CAL_DEEP       (est_error_O2cal_deep3, est_error_O2cal_deep2, est_error_O2cal_deep1) float64 ...
#     EST_ERROR_O2CAL_SURF       (est_error_O2cal_surf3, est_error_O2cal_surf2, est_error_O2cal_surf1) float64 ...
#     PCT_ERROR_O2CAL            (pct_error_O2cal3, pct_error_O2cal2, pct_error_O2cal1) float64 ...
#     PCT_ERROR_O2CAL_DEEP       (pct_error_O2cal_deep3, pct_error_O2cal_deep2, pct_error_O2cal_deep1) float64 ...
#     PCT_ERROR_O2CAL_SURF       (pct_error_O2cal_surf3, pct_error_O2cal_surf2, pct_error_O2cal_surf1) float64 ...
#     NOTES                      (NOTES3, NOTES2) |S1 ...

# %%
# Find oxygen values
oxygen_data1 = data_oxygen['OXYGEN_UW_CORRECTED'].values
print(oxygen_data1)
# Out:
# [[[239.13647681 238.00848695 240.04190159 ... 256.78185058 259.10783008
#    259.54804937]
#   [239.16036023 238.02115904 240.02141387 ... 256.83982963 259.23532447
#    259.73204264]
#   [239.15502695 238.04799    239.96655449 ... 256.79297907 258.9479965
#    259.62091404]
#   ...
#   [178.79356388 179.63769527 166.19530651 ... 165.5449598           nan
#             nan]
#   [171.25388805 172.23624366          nan ...          nan          nan
#             nan]
#   [166.26764132 166.58852119          nan ...          nan          nan
#             nan]]]

# %%
print("Dimensions of oxygen_data1:", np.ndim(oxygen_data1))
flatoxy_data = oxygen_data1.flatten()
# Out:
# Dimensions of oxygen_data1: 3

# %%
rounded_oxygen = np.round(oxygen_data1, 1)
rounded_oxygen_data = np.round(picophytopl_data, 1) #Rounding makes the graph less messy

# %%
# Graph for Oxygen (3 dimensional data)
oxygen_data1 = data_oxygen['OXYGEN_UW_CORRECTED'].values
#Flatten the 3D data
y_data_flattened = data_oxygen['OXYGEN_UW_CORRECTED'].values.flatten()

# Create an x array of the same length
x_data = np.arange(len(y_data_flattened))

# Plot
plt.scatter(y_data_flattened, x_data)
plt.xlabel('Oxygen Concentration (mole kg^-1)')
plt.ylabel('Depth')
plt.gca().invert_yaxis()
plt.show()
plt.savefig('figure3ocean215.png')
